# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/saksh/OneDrive/Desktop/Laptop_price.xlsx")

# %%
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 54.8+ KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
df["Brand"].unique()
# Out:
# array(['Asus', 'Acer', 'Lenovo', 'HP', 'Dell'], dtype=object)

# %%
#na values duplicated values

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
#df.isna().sum().sum()

# %%
#df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#data.drop_duplicates(inplace=True)

# %%
df.head(2)
# Out:
#   Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0  Asus         3.830296        16               512    11.185147  2.641094
# 1  Acer         2.912833         4              1000    11.311372  3.260012
#
#           Price
# 0  17395.093065
# 1  31607.605919

# %%
df.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
numeric_data=df.select_dtypes(include=["number"])

# %%
numeric_data.corr()
# Out:
#                   Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# Processor_Speed          1.000000  0.021391         -0.067576    -0.013425
# RAM_Size                 0.021391  1.000000          0.002111    -0.036002
# Storage_Capacity        -0.067576  0.002111          1.000000    -0.027560
# Screen_Size             -0.013425 -0.036002         -0.027560     1.000000
# Weight                  -0.054603 -0.025382          0.041335     0.021995
# Price                   -0.050737  0.061237          0.997908    -0.026740
#
#                     Weight     Price
# Processor_Speed  -0.054603 -0.050737
# RAM_Size         -0.025382  0.061237
# Storage_Capacity  0.041335  0.997908
# Screen_Size       0.021995 -0.026740
# Weight            1.000000  0.038417
# Price             0.038417  1.000000

# %%
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
df.groupby("Brand")["Price"].mean()
# Out:
# Brand
# Acer      19984.613620
# Asus      19854.238277
# Dell      18866.009978
# HP        19369.762930
# Lenovo    19974.929725
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("Brand")["Price"].mean().head(2).sort_values(ascending=False).plot(kind="bar")
plt.title("Average prices by brands")
plt.ylabel("Average Price")
plt.show()

# %%
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
df.groupby("RAM_Size")["Brand"].value_counts().reset_index()
# Out:
#     RAM_Size   Brand  count
# 0          4      HP     59
# 1          4    Acer     50
# 2          4    Dell     48
# 3          4    Asus     47
# 4          4  Lenovo     39
# 5          8    Asus     66
# 6          8  Lenovo     51
# 7          8    Acer     48
# 8          8    Dell     43
# 9          8      HP     38
# 10        16    Dell     52
# 11        16      HP     49
# 12        16    Acer     47
# 13        16    Asus     47
# 14        16  Lenovo     42
# 15        32    Dell     67
# 16        32    Acer     59
# 17        32  Lenovo     58
# 18        32    Asus     46
# 19        32      HP     44

# %%
df["Brand"].value_counts().sort_values(ascending=False).plot(kind="pie")
plt.title("Brand Distribution by Data")
plt.ylabel("")
plt.show()

# %%
df["Brand"].value_counts()
# Out:
# Brand
# Dell      210
# Asus      206
# Acer      204
# Lenovo    190
# HP        190
# Name: count, dtype: int64

# %%
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
#        'Screen_Size', 'Weight', 'Price'],
#       dtype='object')

# %%
y=df["Price"]
x=df[['Processor_Speed', 'RAM_Size', 'Storage_Capacity']]

# %%
x
# Out:
#      Processor_Speed  RAM_Size  Storage_Capacity
# 0           3.830296        16               512
# 1           2.912833         4              1000
# 2           3.241627         4               256
# 3           3.806248        16               512
# 4           3.268097        32              1000
# ..               ...       ...               ...
# 995         3.343584         4              1000
# 996         2.780555         8               256
# 997         3.200569         4               512
# 998         1.604182         8               256
# 999         1.711980         4               256
#
# [1000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 800

# %%
len(y_train)
# Out:
# 800

# %%
len(x_test)
# Out:
# 200

# %%
len(y_test)
# Out:
# 200

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfrmodel=RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_gridrfr={"max_depth":[2,5,10,15,20,25],
               "max_features":["auto","log2"],
               "n_estimators":[2,4,6,8,10,12]}

# %%
gridrfr=GridSearchCV(rfrmodel,param_gridrfr)

# %%
gridrfr.fit(x_train,y_train)
# Out:
# c:\Users\saksh\OneDrive\Desktop\Laptop_price_prediction\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 180 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\saksh\OneDrive\Desktop\Laptop_price_prediction\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\saksh\OneDrive\Desktop\Laptop_price_prediction\.venv\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
# ...

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}

# %%
predictions=gridrfr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 327.74251351748177

# %%
df["Price"].describe()
# Out:
# count     1000.000000
# mean     19604.187963
# std       9406.064880
# min       8570.012950
# 25%      10114.012948
# 50%      17287.241878
# 75%      31566.214754
# max      33503.935037
# Name: Price, dtype: float64

# %%
x.columns
# Out:
# Index(['Processor_Speed', 'RAM_Size', 'Storage_Capacity'], dtype='object')

# %%
gridrfr
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [2, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]})

# %%
import joblib
joblib.dump(gridrfr,"rf_model.pkl")
# Out:
# ['rf_model.pkl']
